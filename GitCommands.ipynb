# %%
# !pwd
# Out:
# /content

# %%
#INPUTS

#repoPath should start with the path 
#'/content/gdrive/My Drive/' and go to the folder where the git repo is, and should end with the name of the repo:
repoPath = '/content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/textSimilarityUsingWordMoversDistance'
userEmail = 'sanmesh1@gmail.com'
userName = 'sanmesh1'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········

# %%
import os
os.chdir(repoPath)
#%cd gdrive/My Drive/project_folder/TextSimilarityUsingWord2Vec

# %%
# !git config --global user.email $userEmail
#!git config --global user.name "sanmeshkumar udhayakumar"
# !git config --global user.name $userName

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .
# !git commit -m "got wmd csv output creation fully working for 1 query item. next step is to include similarity from cosine similarity, be able to use fasttext model instead, and be able to search items similar to ones from every query"
# !git push
# Out:
# [master eb18c74] added new notebook with functions and classes, and it outputs an excel sheet
#  7 files changed, 1506 insertions(+), 2 deletions(-)
#  rewrite GitCommands.ipynb (89%)
#  create mode 100644 WMD_tutorial.ipynb
#  create mode 100644 data/aa_combined-20110321.csv
#  create mode 100644 download_destination_folder_with_slash_at_end/aa_combined-20110321.csv.gz
#  rewrite itemSimilarityWithWMD.ipynb (95%)
#  create mode 100644 itemSimilarityWithWMD_WithLosssFunctionV1.ipynb
#  create mode 100644 output.csv
# Counting objects: 11, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 163.65 KiB | 5.11 MiB/s, done.
# Total 11 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/sanmesh1/textSimilarityUsingWordMoversDistance.git
#    64b6f67..eb18c74  master -> master
