# %%
# !pwd
# Out:
# /content

# %%
#INPUTS

#repoPath should start with the path 
#'/content/gdrive/My Drive/' and go to the folder where the git repo is, and should end with the name of the repo:
repoPath = '/content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/textSimilarityUsingWordMoversDistance'
userEmail = 'sanmesh1@gmail.com'
userName = 'sanmesh1'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir(repoPath)
#%cd gdrive/My Drive/project_folder/TextSimilarityUsingWord2Vec

# %%
# !git config --global user.email $userEmail
#!git config --global user.name "sanmeshkumar udhayakumar"
# !git config --global user.name $userName

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .
# !git commit -m "got csv labelling to work properly and changed field name of preprocessed data to be more general and comb. next step is to include similarity from cosine similarity, be able to use fasttext model instead, and be able to search items similar to ones from every query"
# !git push
# Out:
# [master 7322c28] got wmd csv output creation fully working for 1 query item. next step is to include similarity from cosine similarity, be able to use fasttext model instead, and be able to search items similar to ones from every query
#  3 files changed, 13 insertions(+), 13 deletions(-)
#  rewrite itemSimilarityWithWMD_WithLosssFunctionV1.ipynb (98%)
#  rewrite output.csv (99%)
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.62 KiB | 536.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/sanmesh1/textSimilarityUsingWordMoversDistance.git
#    eb18c74..7322c28  master -> master
