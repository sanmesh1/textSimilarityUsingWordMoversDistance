# %%
# !pwd
# Out:
# /content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/IntegratingClonedGithubRepoWithGoogleColabAndGithubControl

# %%
#INPUTS

#repoPath should start with the path 
#'/content/gdrive/My Drive/' and go to the folder where the git repo is, and should end with the name of the repo:
repoPath = '/content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/textSimilarityUsingWordMoversDistance'
userEmail = 'sanmesh1@gmail.com'
userName = 'sanmesh1'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir(repoPath)
#%cd gdrive/My Drive/project_folder/TextSimilarityUsingWord2Vec

# %%
# !git config --global user.email $userEmail
#!git config --global user.name "sanmeshkumar udhayakumar"
# !git config --global user.name $userName

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .
# !git commit -m "added notebooks with messy implementation of wmd"
# !git push
# Out:
# [master dffd1cb] added notebooks with messy implementation of wmd
#  4 files changed, 14 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 GitCommands.ipynb
#  create mode 100644 itemSimilarityWithWMD.ipynb
#  create mode 100644 testingWMD.ipynb
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 8.05 KiB | 915.00 KiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/sanmesh1/textSimilarityUsingWordMoversDistance.git
#    3f5ec92..dffd1cb  master -> master
