# %%
# !pwd
# Out:
# /content

# %%
#INPUTS

#repoPath should start with the path 
#'/content/gdrive/My Drive/' and go to the folder where the git repo is, and should end with the name of the repo:
repoPath = '/content/gdrive/My Drive/TestingGitCloneIntoGoogleDrive/textSimilarityUsingWordMoversDistance'
userEmail = 'sanmesh1@gmail.com'
userName = 'sanmesh1'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir(repoPath)
#%cd gdrive/My Drive/project_folder/TextSimilarityUsingWord2Vec

# %%
# !git config --global user.email $userEmail
#!git config --global user.name "sanmeshkumar udhayakumar"
# !git config --global user.name $userName

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add *
# !git commit -m "got accuracy function added"
# !git push
# Out:
# error: open("csv_logs_06_12_20/searchQuery_PS2 controller USB_numMatches_20.gsheet"): Operation not supported
# error: unable to index file csv_logs_06_12_20/searchQuery_PS2 controller USB_numMatches_20.gsheet
# fatal: adding files failed
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Changes not staged for commit:
# 	modified:   GitCommands.ipynb
# 	modified:   itemSimilarityWithWMD_WithLosssFunctionV1.ipynb
# 	deleted:    searchQuery_Bluray Hobbit extended_numMatches_20.csv
# 	deleted:    searchQuery_Brett Favre NY Titans jersey blue_numMatches_20.csv
# 	deleted:    searchQuery_LED monitor_numMatches_20.csv
# 	deleted:    searchQuery_PS2 controller USB_numMatches_20.csv
# 	deleted:    searchQuery_Vanilla Scented Perfumes_numMatches_20.csv
# 	deleted:    searchQuery_aroma diffuser_numMatches_20.csv
# 	deleted:    searchQuery_bedspreads_numMatches_20.csv
# 	deleted:    searchQuery_coffee grinder_numMatches_20.csv
# 	deleted:    searchQuery_double stroller_numMatches_20.csv
# 	deleted:    searchQuery_extenal hardisk 500 gb_numMatches_20.csv
# 	deleted:    searchQuery_eye cream_numMatches_20.csv
# 	deleted:    searchQuery_face cream_numMatches_20.csv
# 	deleted:    searchQuery_high chairs_numMatches_20.csv
# 	deleted:    searchQuery_kitchen rugs_numMatches_20.csv
# 	deleted:    searchQuery_laptop lenovo_numMatches_20.csv
# 	deleted:    searchQuery_playstation 4_numMatches_20.csv
# 	deleted:    searchQuery_routers_numMatches_20.csv
# 	deleted:    searchQuery_shaver panasonic_numMatches_20.csv
# 	deleted:    searchQuery_spiderman_numMatches_20.csv
# 	deleted:    searchQuery_white plain dinner set_numMatches_20.csv
# 	deleted:    searchQuery_wireless mouse_numMatches_20.csv
#
# Untracked files:
# 	csv_logs_06_12_20/
# 	csv_logs_only_title_06_14_20/
# 	csv_logs_with_textrank_06_14_20/
#
# no changes added to commit
# Everything up-to-date
